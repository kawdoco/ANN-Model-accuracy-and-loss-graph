# %%
from datetime import datetime
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers.core import Dense
from keras.callbacks import TensorBoard

# the four different states of the XOR gate
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# the four expected results in the same order
target_data = np.array([[0],[1],[1],[0]], "float32")

model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(32 , activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

#logdir="logs\\fit2\\" + datetime.now().strftime("%Y%m%d-%H%M%S")
#tensorboard_callback =  TensorBoard(log_dir=logdir)

history=model.fit(training_data, target_data, epochs=100, verbose=2 )


import matplotlib.pyplot as plt
plt.plot(history.history['binary_accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

for layer in model.layers:
    g=layer.get_config()
    h=layer.get_weights()
    print (g)
    print (h)

#print model.predict(training_data).round()
# Out:
# Using TensorFlow backend.
# Epoch 1/100
#  - 1s - loss: 0.2486 - binary_accuracy: 0.7500
# Epoch 2/100
#  - 0s - loss: 0.2474 - binary_accuracy: 0.5000
# Epoch 3/100
#  - 0s - loss: 0.2462 - binary_accuracy: 0.5000
# Epoch 4/100
#  - 0s - loss: 0.2450 - binary_accuracy: 0.5000
# Epoch 5/100
#  - 0s - loss: 0.2438 - binary_accuracy: 0.7500
# Epoch 6/100
#  - 0s - loss: 0.2427 - binary_accuracy: 0.7500
# Epoch 7/100
#  - 0s - loss: 0.2416 - binary_accuracy: 0.7500
# Epoch 8/100
#  - 0s - loss: 0.2406 - binary_accuracy: 0.7500
# Epoch 9/100
#  - 0s - loss: 0.2396 - binary_accuracy: 0.7500
# Epoch 10/100
#  - 0s - loss: 0.2385 - binary_accuracy: 0.7500
# Epoch 11/100
#  - 0s - loss: 0.2375 - binary_accuracy: 0.7500
# Epoch 12/100
#  - 0s - loss: 0.2366 - binary_accuracy: 0.7500
# Epoch 13/100
#  - 0s - loss: 0.2357 - binary_accuracy: 0.7500
# Epoch 14/100
#  - 0s - loss: 0.2348 - binary_accuracy: 1.0000
# Epoch 15/100
#  - 0s - loss: 0.2339 - binary_accuracy: 1.0000
# Epoch 16/100
#  - 0s - loss: 0.2330 - binary_accuracy: 1.0000
# Epoch 17/100
#  - 0s - loss: 0.2321 - binary_accuracy: 1.0000
# Epoch 18/100
#  - 0s - loss: 0.2311 - binary_accuracy: 1.0000
# Epoch 19/100
#  - 0s - loss: 0.2302 - binary_accuracy: 1.0000
# Epoch 20/100
#  - 0s - loss: 0.2293 - binary_accuracy: 1.0000
# Epoch 21/100
#  - 0s - loss: 0.2284 - binary_accuracy: 1.0000
# Epoch 22/100
#  - 0s - loss: 0.2274 - binary_accuracy: 1.0000
# Epoch 23/100
#  - 0s - loss: 0.2265 - binary_accuracy: 1.0000
# Epoch 24/100
#  - 0s - loss: 0.2255 - binary_accuracy: 1.0000
# Epoch 25/100
#  - 0s - loss: 0.2246 - binary_accuracy: 1.0000
# Epoch 26/100
#  - 0s - loss: 0.2238 - binary_accuracy: 1.0000
# Epoch 27/100
#  - 0s - loss: 0.2229 - binary_accuracy: 1.0000
# Epoch 28/100
#  - 0s - loss: 0.2221 - binary_accuracy: 1.0000
# Epoch 29/100
#  - 0s - loss: 0.2212 - binary_accuracy: 1.0000
# Epoch 30/100
#  - 0s - loss: 0.2203 - binary_accuracy: 1.0000
# Epoch 31/100
#  - 0s - loss: 0.2195 - binary_accuracy: 1.0000
# Epoch 32/100
#  - 0s - loss: 0.2187 - binary_accuracy: 1.0000
# Epoch 33/100
#  - 0s - loss: 0.2179 - binary_accuracy: 1.0000
# Epoch 34/100
#  - 0s - loss: 0.2171 - binary_accuracy: 1.0000
# Epoch 35/100
#  - 0s - loss: 0.2163 - binary_accuracy: 1.0000
# Epoch 36/100
#  - 0s - loss: 0.2156 - binary_accuracy: 1.0000
# Epoch 37/100
#  - 0s - loss: 0.2148 - binary_accuracy: 1.0000
# Epoch 38/100
#  - 0s - loss: 0.2140 - binary_accuracy: 1.0000
# Epoch 39/100
#  - 0s - loss: 0.2132 - binary_accuracy: 1.0000
# Epoch 40/100
#  - 0s - loss: 0.2124 - binary_accuracy: 1.0000
# Epoch 41/100
#  - 0s - loss: 0.2115 - binary_accuracy: 1.0000
# Epoch 42/100
#  - 0s - loss: 0.2107 - binary_accuracy: 1.0000
# Epoch 43/100
#  - 0s - loss: 0.2099 - binary_accuracy: 1.0000
# Epoch 44/100
#  - 0s - loss: 0.2091 - binary_accuracy: 1.0000
# Epoch 45/100
#  - 0s - loss: 0.2083 - binary_accuracy: 1.0000
# Epoch 46/100
#  - 0s - loss: 0.2076 - binary_accuracy: 1.0000
# Epoch 47/100
#  - 0s - loss: 0.2068 - binary_accuracy: 1.0000
# Epoch 48/100
#  - 0s - loss: 0.2059 - binary_accuracy: 1.0000
# Epoch 49/100
#  - 0s - loss: 0.2051 - binary_accuracy: 1.0000
# Epoch 50/100
#  - 0s - loss: 0.2042 - binary_accuracy: 1.0000
# Epoch 51/100
#  - 0s - loss: 0.2034 - binary_accuracy: 1.0000
# Epoch 52/100
#  - 0s - loss: 0.2026 - binary_accuracy: 1.0000
# Epoch 53/100
#  - 0s - loss: 0.2017 - binary_accuracy: 1.0000
# Epoch 54/100
#  - 0s - loss: 0.2009 - binary_accuracy: 1.0000
# Epoch 55/100
#  - 0s - loss: 0.2000 - binary_accuracy: 1.0000
# Epoch 56/100
#  - 0s - loss: 0.1992 - binary_accuracy: 1.0000
# Epoch 57/100
#  - 0s - loss: 0.1984 - binary_accuracy: 1.0000
# Epoch 58/100
#  - 0s - loss: 0.1975 - binary_accuracy: 1.0000
# Epoch 59/100
#  - 0s - loss: 0.1967 - binary_accuracy: 1.0000
# Epoch 60/100
#  - 0s - loss: 0.1958 - binary_accuracy: 1.0000
# Epoch 61/100
#  - 0s - loss: 0.1949 - binary_accuracy: 1.0000
# Epoch 62/100
#  - 0s - loss: 0.1940 - binary_accuracy: 1.0000
# Epoch 63/100
#  - 0s - loss: 0.1931 - binary_accuracy: 1.0000
# Epoch 64/100
#  - 0s - loss: 0.1922 - binary_accuracy: 1.0000
# Epoch 65/100
#  - 0s - loss: 0.1913 - binary_accuracy: 1.0000
# Epoch 66/100
#  - 0s - loss: 0.1905 - binary_accuracy: 1.0000
# Epoch 67/100
#  - 0s - loss: 0.1896 - binary_accuracy: 1.0000
# Epoch 68/100
#  - 0s - loss: 0.1887 - binary_accuracy: 1.0000
# Epoch 69/100
#  - 0s - loss: 0.1879 - binary_accuracy: 1.0000
# Epoch 70/100
#  - 0s - loss: 0.1870 - binary_accuracy: 1.0000
# Epoch 71/100
#  - 0s - loss: 0.1861 - binary_accuracy: 1.0000
# Epoch 72/100
#  - 0s - loss: 0.1852 - binary_accuracy: 1.0000
# Epoch 73/100
#  - 0s - loss: 0.1843 - binary_accuracy: 1.0000
# Epoch 74/100
#  - 0s - loss: 0.1834 - binary_accuracy: 1.0000
# Epoch 75/100
#  - 0s - loss: 0.1824 - binary_accuracy: 1.0000
# Epoch 76/100
#  - 0s - loss: 0.1815 - binary_accuracy: 1.0000
# Epoch 77/100
#  - 0s - loss: 0.1806 - binary_accuracy: 1.0000
# Epoch 78/100
#  - 0s - loss: 0.1796 - binary_accuracy: 1.0000
# Epoch 79/100
#  - 0s - loss: 0.1787 - binary_accuracy: 1.0000
# Epoch 80/100
#  - 0s - loss: 0.1777 - binary_accuracy: 1.0000
# Epoch 81/100
#  - 0s - loss: 0.1768 - binary_accuracy: 1.0000
# Epoch 82/100
#  - 0s - loss: 0.1758 - binary_accuracy: 1.0000
# Epoch 83/100
#  - 0s - loss: 0.1748 - binary_accuracy: 1.0000
# Epoch 84/100
#  - 0s - loss: 0.1738 - binary_accuracy: 1.0000
# Epoch 85/100
#  - 0s - loss: 0.1728 - binary_accuracy: 1.0000
# Epoch 86/100
#  - 0s - loss: 0.1718 - binary_accuracy: 1.0000
# Epoch 87/100
#  - 0s - loss: 0.1708 - binary_accuracy: 1.0000
# Epoch 88/100
#  - 0s - loss: 0.1697 - binary_accuracy: 1.0000
# Epoch 89/100
#  - 0s - loss: 0.1688 - binary_accuracy: 1.0000
# Epoch 90/100
#  - 0s - loss: 0.1678 - binary_accuracy: 1.0000
# Epoch 91/100
#  - 0s - loss: 0.1667 - binary_accuracy: 1.0000
# Epoch 92/100
#  - 0s - loss: 0.1657 - binary_accuracy: 1.0000
# Epoch 93/100
#  - 0s - loss: 0.1646 - binary_accuracy: 1.0000
# Epoch 94/100
#  - 0s - loss: 0.1636 - binary_accuracy: 1.0000
# Epoch 95/100
#  - 0s - loss: 0.1625 - binary_accuracy: 1.0000
# Epoch 96/100
#  - 0s - loss: 0.1615 - binary_accuracy: 1.0000
# Epoch 97/100
#  - 0s - loss: 0.1604 - binary_accuracy: 1.0000
# Epoch 98/100
#  - 0s - loss: 0.1593 - binary_accuracy: 1.0000
# Epoch 99/100
#  - 0s - loss: 0.1583 - binary_accuracy: 1.0000
# Epoch 100/100
#  - 0s - loss: 0.1572 - binary_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-70758ef7d19d> in <module>
#      35 plt.xlabel('epoch')
#      36 plt.legend(['train', 'val'], loc='upper left')
# ---> 37 plt.show()
#      38
#      39 for layer in model.layers:
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2061                         orientation=orientation,
#    2062                         dryrun=True,
# -> 2063                         **kwargs)
#    2064                     renderer = self.figure._cachedRenderer
#    2065                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
# --> 532                                self.figure.dpi, metadata=metadata)
#     533
#     534     def print_to_buffer(self):
#
# KeyboardInterrupt:

# %%
# %reload_ext tensorboard

# %%
# %tensorboard --logdir C:\Users\Susara\Documents\ANN\logs\fit2\20200208-115630
# Out:
# Reusing TensorBoard on port 6006 (pid 3976), started 0:28:44 ago. (Use '!kill 3976' to kill it.)
#       <iframe id="tensorboard-frame-a4b1942d7d6b0a32" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a4b1942d7d6b0a32");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
